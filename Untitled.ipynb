# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
df2= pd.read_csv('movies/final_tmdb_data_2001.csv.gz')
df2
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg
# 2     tt0079644    0.0  /79axmuH1UGkB7m72jjB9rPff9om.jpg
# 3     tt0089067    0.0                               NaN
# 4     tt0114447    0.0                               NaN
# ...         ...    ...                               ...
# 2210  tt8795764    0.0                               NaN
# 2211  tt8929248    0.0                               NaN
# 2212  tt9071078    0.0                               NaN
# 2213  tt9099724    0.0                               NaN
# 2214  tt9798698    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  48000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN         0.0
# ...

# %%
df1= pd.read_csv('movies/final_tmdb_data_2000.csv.gz')
df1
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg
# 2     tt0079644    0.0  /79axmuH1UGkB7m72jjB9rPff9om.jpg
# 3     tt0089067    0.0                               NaN
# 4     tt0114447    0.0                               NaN
# ...         ...    ...                               ...
# 2210  tt8795764    0.0                               NaN
# 2211  tt8929248    0.0                               NaN
# 2212  tt9071078    0.0                               NaN
# 2213  tt9099724    0.0                               NaN
# 2214  tt9798698    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  48000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN         0.0
# ...
